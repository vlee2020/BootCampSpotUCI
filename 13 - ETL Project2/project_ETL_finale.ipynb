# %% [markdown]
# ## Project 2: ETL
# Extraction (E) and Transform (T) steps will be performed in this jupyter notebook.
# Load (L) will be performed in PostGres.

# %%
# Dependencies
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %% [markdown]
# ##     Step 1:  Extract Data

# %%
# csv file variable assignments
goodreads_path = "Resources/book_data.csv"
google_path = "Resources/google_books_1299.csv"
nyt_path = "Resources/books_uniq_weeks.csv"

# Import csv files as dataframes
goodreads_rdf = pd.read_csv(goodreads_path)
google_rdf = pd.read_csv(google_path, encoding="ANSI")
nyt_rdf = pd.read_csv(nyt_path, encoding="ISO-8859-1")

#goodreads_rdf.head()
#google_rdf.head()
nyt_rdf.head()
# Out:
#        publisher  dagger                                   book_review_link  \
# 0      Riverhead       0  https://www.nytimes.com/2015/01/05/books/the-g...
# 1       Scribner       0                                                NaN
# 2        Vintage       0                                                NaN
# 3   St. Martin's       0                                                NaN
# 4  Penguin Group       0  https://www.nytimes.com/2009/02/19/books/19mas...
#
#              author primary_isbn10  price primary_isbn13  \
# 0     Paula Hawkins     1594634025      0    9.78159E+12
# 1     Anthony Doerr     1501173219      0     9.7815E+12
# 2         E L James      525431888      0    9.78053E+12
# 3    Kristin Hannah     1466850604      0    9.78147E+12
# 4  Kathryn Stockett     1440697663      0    9.78144E+12
#
#                                   sunday_review_link      date  \
# 0  https://www.nytimes.com/2015/02/01/books/revie...   2/19/17
# 1  https://www.nytimes.com/2014/05/11/books/revie...    5/7/17
# 2                                                NaN    3/5/17
# 3                                                NaN  10/29/17
# 4                                                NaN    4/8/12
#
#   first_chapter_link          contributor                        title  \
# 0                NaN     by Paula Hawkins        THE GIRL ON THE TRAIN
# 1                NaN     by Anthony Doerr  ALL THE LIGHT WE CANNOT SEE
# 2                NaN       by E. L. James          FIFTY SHADES DARKER
# 3                NaN    by Kristin Hannah              THE NIGHTINGALE
# 4                NaN  by Kathryn Stockett                     THE HELP
#
#    age_group  weeks_on_list
# 0        NaN            102
# 1        NaN             81
# 2        NaN             66
# 3        NaN             63
# 4        NaN             58

# %% [markdown]
# ## Step 2:  Transform - prep the data for Load (L) step.

# %%
# We discovered last minute (cry) that these Kraggle files had many duplicated ISBNS for books of different titles/authors

goodreads_rdf = goodreads_rdf.drop_duplicates(subset=['book_isbn'])
google_rdf = google_rdf.drop_duplicates(subset=['ISBN'])

# %%
# Convert ISBN to string

goodreads_rdf['book_isbn'] = goodreads_rdf['book_isbn'].astype("str")
#goodreads_rdf.dtypes
goodreads_rdf.head()
#google_rdf.dtypes
# Out:
#                                         book_authors  \
# 0                                    Suzanne Collins
# 2                                         Harper Lee
# 3  Jane Austen|Anna Quindlen|Mrs. Oliphant|George...
# 4                                    Stephenie Meyer
# 5                                       Markus Zusak
#
#                                            book_desc  \
# 0  Winning will make you famous. Losing means cer...
# 2  The unforgettable novel of a childhood in a sl...
# 3  «È cosa ormai risaputa che a uno scapolo in po...
# 4  About three things I was absolutely positive.F...
# 5  Trying to make sense of the horrors of World W...
#
#                          book_edition book_format      book_isbn book_pages  \
# 0                                 NaN   Hardcover  9780440000000  374 pages
# 2                    50th Anniversary   Paperback  9780060000000  324 pages
# 3  Modern Library Classics, USA / CAN   Paperback  9780680000000  279 pages
# 4                                 NaN   Paperback  9780320000000  498 pages
# 5   First American Edition (US / CAN)   Hardcover  9780380000000  552 pages
#
#    book_rating  book_rating_count  book_review_count             book_title  \
# 0         4.33            5519135             160706       The Hunger Games
# 2         4.27            3745197              79450  To Kill a Mockingbird
# 3         4.25            2453620              54322    Pride and Prejudice
# 4         3.58            4281268              97991               Twilight
# 5         4.36            1485632             100821         The Book Thief
#
#                                               genres  \
# 0  Young Adult|Fiction|Science Fiction|Dystopia|F...
# 2  Classics|Fiction|Historical|Historical Fiction...
# 3                           Classics|Fiction|Romance
# 4  Young Adult|Fantasy|Romance|Paranormal|Vampire...
# 5  Historical|Historical Fiction|Fiction|Young Adult
#
#                                            image_url
# 0  https://images.gr-assets.com/books/1447303603l...
# 2  https://images.gr-assets.com/books/1361975680l...
# 3  https://images.gr-assets.com/books/1320399351l...
# 4  https://images.gr-assets.com/books/1361039443l...
# 5  https://images.gr-assets.com/books/1522157426l...

# %%
# Convert ISBN to string

google_rdf['ISBN'] = google_rdf['ISBN'].astype("str")
#google_rdf.dtypes
google_rdf.head()
#google_rdf.dtypes
# Out:
#    Unnamed: 0                                             title  \
# 0           0                        Attack on Titan: Volume 13
# 1           1  Antiques Roadkill: A Trash 'n' Treasures Mystery
# 2           2                    The Art of Super Mario Odyssey
# 3           3    Getting Away Is Deadly: An Ellie Avery Mystery
# 4           4         The Painted Man (The Demon Cycle, Book 1)
#
#            author  rating voters   price currency  \
# 0  Hajime Isayama     4.6    428   43.28      SAR
# 1   Barbara Allan     3.3     23   26.15      SAR
# 2        Nintendo     3.9      9  133.85      SAR
# 3     Sara Rosett     4.0     10   26.15      SAR
# 4  Peter V. Brett     4.5    577   28.54      SAR
#
#                                          description  \
# 0  NO SAFE PLACE LEFT At great cost to the Garris...
# 1  Determined to make a new start in her quaint h...
# 2  Take a globetrotting journey all over the worl...
# 3  With swollen feet and swelling belly, pregnant...
# 4  The stunning debut fantasy novel from author P...
#
#                      publisher  page_count  \
# 0              Kodansha Comics       192.0
# 1  Kensington Publishing Corp.       288.0
# 2            Dark Horse Comics       368.0
# 3  Kensington Publishing Corp.       320.0
# 4             HarperCollins UK       544.0
#
#                                              generes           ISBN language  \
# 0                                               none  9781610000000  English
# 1  Fiction , Mystery &amp, Detective , Cozy , Gen...  9780760000000  English
# 2    Games &amp, Activities , Video &amp, Electronic  9781510000000  English
# 3                                               none  9781620000000  English
# 4                   Fiction , Fantasy , Dark Fantasy  9780010000000  English
#
#   published_date
# 0      31-Jul-14
# 1       1-Jul-07
# 2       5-Nov-19
# 3       1-Mar-09
# 4       8-Jan-09

# %%
# Extract interested GOODREADS data fields into new dataframe
goodreads_df = goodreads_rdf[['book_isbn', 
                              'book_authors', 
                              'book_title', 
                              'book_desc', 
                              'book_edition',
                              'book_rating', 
                              'book_pages', 
                              'book_format', 
                              'genres', 
                              'image_url']]

# Rename headers as needed
goodreads_df.rename(columns={'book_isbn': 'isbn', 
                             'book_authors': 'gr_author', 
                             'book_title': 'gr_title', 
                             'book_desc': 'gr_desc', 
                             'book_edition': 'gr_edition',
                             'book_rating': 'goodreads_rating', 
                             'book_pages': 'gr_pages', 
                             'book_format': 'gr_format', 
                             'genres': 'gr_genres'}, inplace=True)



#goodreads_df.head()
#goodreads_df.count()
goodreads_df['isbn'].value_counts()
# Out:
# C:\Users\nvkar\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4301: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# 9783870000000    1
# 9785950000000    1
# 9780910000000    1
# 789112000000     1
# 9781800000000    1
#                 ..
# 9789800000000    1
# 9780370000000    1
# 9783790000000    1
# 9781040000000    1
# 9788370000000    1
# Name: isbn, Length: 549, dtype: int64

# %%
# Extract interested GOOGLE data fields into new dataframe
google_df = google_rdf[['ISBN', 
                        'author', 
                        'title', 
                        'rating', 
                        'price', 
                        'currency', 
                        'description', 
                        'publisher', 
                        'page_count', 
                        'generes', 
                        'published_date']]

# Rename headers as needed
google_df.rename(columns={'ISBN':'isbn', 
                             'author':'gg_author', 
                             'title':'gg_title', 
                             'rating':'gg_rating', 
                             'price':'gg_price', 
                             'currency':'gg_currency', 
                             'description':'gg_description', 
                             'publisher':'gg_publisher', 
                             'page_count':'gg_pages', 
                             'generes':'gg_genres', 
                             'published_date':'gg_published_date'}, inplace=True)

google_df.rename(columns={'ISBN':'isbn'}, inplace=True)


#google_df.dtypes
#google_df.head()
#google_df.count()
google_df['isbn'].value_counts()
# Out:
# 9780680000000    1
# 9780550000000    1
# 9781600000000    1
# 9780140000000    1
# 9781400000000    1
#                 ..
# 9781740000000    1
# 9781520000000    1
# 9780070000000    1
# 9781430000000    1
# 9780430000000    1
# Name: isbn, Length: 66, dtype: int64

# %%
# Merge google and goodreads data to form the beginnings of the book table
books_df = pd.merge(goodreads_df, google_df, on="isbn", how="inner")
books_df['isbn'].value_counts()
# Out:
# 9780400000000    1
# 9781470000000    1
# 9780140000000    1
# 9781640000000    1
# 9781400000000    1
#                 ..
# 9781520000000    1
# 9780070000000    1
# 9781430000000    1
# 9780360000000    1
# 9780430000000    1
# Name: isbn, Length: 62, dtype: int64

# %%
books_df.count()
# Out:
# isbn                 62
# gr_author            62
# gr_title             62
# gr_desc              61
# gr_edition           18
# goodreads_rating     62
# gr_pages             61
# gr_format            61
# gr_genres            59
# image_url            61
# gg_author            62
# gg_title             62
# gg_rating            59
# gg_price             62
# gg_currency          62
# gg_description       62
# gg_publisher         62
# gg_pages             62
# gg_genres            62
# gg_published_date    62
# dtype: int64

# %%
books_df.dtypes
# Out:
# isbn                  object
# gr_author             object
# gr_title              object
# gr_desc               object
# gr_edition            object
# goodreads_rating     float64
# gr_pages              object
# gr_format             object
# gr_genres             object
# image_url             object
# gg_author             object
# gg_title              object
# gg_rating            float64
# gg_price             float64
# gg_currency           object
# gg_description        object
# gg_publisher          object
# gg_pages             float64
# gg_genres             object
# gg_published_date     object
# dtype: object

# %%
books_df.head()
# Out:
#             isbn                                          gr_author  \
# 0  9780060000000                                         Harper Lee
# 1  9780680000000  Jane Austen|Anna Quindlen|Mrs. Oliphant|George...
# 2  9780070000000                          C.S. Lewis|Pauline Baynes
# 3  9780450000000                                      George Orwell
# 4  9780350000000                                     J.R.R. Tolkien
#
#                                             gr_title  \
# 0                              To Kill a Mockingbird
# 1                                Pride and Prejudice
# 2                           The Chronicles of Narnia
# 3                                        Animal Farm
# 4  J.R.R. Tolkien 4-Book Boxed Set: The Hobbit an...
#
#                                              gr_desc  \
# 0  The unforgettable novel of a childhood in a sl...
# 1  «È cosa ormai risaputa che a uno scapolo in po...
# 2  Journeys to the end of the world, fantastic cr...
# 3  مزرعة الحيوانات هي رائعة جورج أورويل الخالدة.....
# 4  لجزء الثالث من ملحمة جيه أر أر تولكين الرائعة ...
#
#                            gr_edition  goodreads_rating    gr_pages  \
# 0                    50th Anniversary              4.27   324 pages
# 1  Modern Library Classics, USA / CAN              4.25   279 pages
# 2                     Reissue Edition              4.25   767 pages
# 3                                 NaN              3.90   122 pages
# 4       Hobbit Movie Tie-in Boxed set              4.59  1728 pages
#
#                gr_format                                          gr_genres  \
# 0              Paperback  Classics|Fiction|Historical|Historical Fiction...
# 1              Paperback                           Classics|Fiction|Romance
# 2              Paperback     Fantasy|Classics|Fiction|Young Adult|Childrens
# 3              Paperback  Classics|Fiction|Science Fiction|Dystopia|Fant...
# 4  Mass Market Paperback                           Fantasy|Fiction|Classics
#
#                                            image_url       gg_author  \
# 0  https://images.gr-assets.com/books/1361975680l...  Jason Schreier
# 1  https://images.gr-assets.com/books/1320399351l...  Charles Duhigg
# 2  https://images.gr-assets.com/books/1449868701l...    David Ulrich
# 3  https://images.gr-assets.com/books/1424037542l...  Madeleine Roux
# 4  https://images.gr-assets.com/books/1346072396l...    Pierce Brown
#
#                                             gg_title  gg_rating  gg_price  \
# 0  Blood, Sweat, and Pixels: The Triumphant, Turb...        4.3     50.25
# 1  The Power of Habit: Why We Do What We Do in Li...        4.1     62.10
# 2  HR from the Outside In: Six Competencies for t...        3.6    133.90
# 3                                           Salvaged        4.0     47.78
# 4                                       Morning Star        4.8     62.10
#
#   gg_currency                                     gg_description  \
# 0         SAR  NATIONAL BESTSELLERDeveloping video gamesâ€”he...
# 1         SAR  NEW YORK TIMESÂ BESTSELLER â€¢ This instant cl...
# 2         SAR  â€œThis definitive work on HR competencies pro...
# 3         SAR  A WOMAN ON THE RUN. A CAPTAIN ADRIFT IN SPACE....
# 4         SAR  #1 NEW YORK TIMES BESTSELLER â€¢Â Red Rising t...
#
#                gg_publisher  gg_pages  \
# 0             HarperCollins     304.0
# 1              Random House     416.0
# 2  McGraw Hill Professional     272.0
# 3                   Penguin     368.0
# 4                   Del Rey     544.0
#
#                                            gg_genres gg_published_date
# 0    Games &amp, Activities , Video &amp, Electronic          5-Sep-17
# 1  Business &amp, Economics , Organizational Beha...         28-Feb-12
# 2                Business &amp, Economics , Training         20-Jul-12
# 3  Fiction , Science Fiction , Action &amp, Adven...         15-Oct-19
# 4  Fiction , Science Fiction , Action &amp, Adven...          9-Feb-16

# %%
# Combine key fields into new column based on conditional logic

books_df['title'] = np.where(books_df['gg_title'] == "", books_df['gr_author'],books_df['gg_title'])
books_df['author'] = np.where(books_df['gg_author'] == "", books_df['gr_author'],books_df['gg_author'])

books_df.count()
# Out:
# isbn                 62
# gr_author            62
# gr_title             62
# gr_desc              61
# gr_edition           18
# goodreads_rating     62
# gr_pages             61
# gr_format            61
# gr_genres            59
# image_url            61
# gg_author            62
# gg_title             62
# gg_rating            59
# gg_price             62
# gg_currency          62
# gg_description       62
# gg_publisher         62
# gg_pages             62
# gg_genres            62
# gg_published_date    62
# title                62
# author               62
# dtype: int64

# %%
final_books_df = books_df[['isbn','title', 'author', 'gg_publisher', 'gg_published_date']]
final_books_df = final_books_df.rename(columns={'gg_publisher':'publisher', 
                             'gg_published_date':'publication_date'}) 
final_books_df
# Out:
#              isbn                                              title  \
# 0   9780060000000  Blood, Sweat, and Pixels: The Triumphant, Turb...
# 1   9780680000000  The Power of Habit: Why We Do What We Do in Li...
# 2   9780070000000  HR from the Outside In: Six Competencies for t...
# 3   9780450000000                                           Salvaged
# 4   9780350000000                                       Morning Star
# ..            ...                                                ...
# 57  9783640000000  Business Process Management: Concepts, Languag...
# 58  9781260000000  Tintinalli's Emergency Medicine: A Comprehensi...
# 59  9788070000000  The Art of War (The Classic Lionel Giles Trans...
# 60  9783740000000                   15 Delicious Slow Cooker Recipes
# 61  9788030000000  The Complete Works of William Shakespeare: All...
#
#                   author                          publisher publication_date
# 0         Jason Schreier                      HarperCollins         5-Sep-17
# 1         Charles Duhigg                       Random House        28-Feb-12
# 2           David Ulrich           McGraw Hill Professional        20-Jul-12
# 3         Madeleine Roux                            Penguin        15-Oct-19
# 4           Pierce Brown                            Del Rey         9-Feb-16
# ..                   ...                                ...              ...
# 57         Mathias Weske  Springer Science & Business Media         3-May-12
# 58  Judith E. Tintinalli           McGraw Hill Professional        22-Oct-19
# 59               Sun Tzu                           e-artnow         2-Jun-12
# 60          Sallie Stone                            BookRix        28-Oct-19
# 61   William Shakespeare                           e-artnow        27-Feb-14
#
# [62 rows x 5 columns]

# %%
# This is the final_books_df to load
final_books_df.head()
# Out:
#             isbn                                              title  \
# 0  9780060000000  Blood, Sweat, and Pixels: The Triumphant, Turb...
# 1  9780680000000  The Power of Habit: Why We Do What We Do in Li...
# 2  9780070000000  HR from the Outside In: Six Competencies for t...
# 3  9780450000000                                           Salvaged
# 4  9780350000000                                       Morning Star
#
#            author                 publisher publication_date
# 0  Jason Schreier             HarperCollins         5-Sep-17
# 1  Charles Duhigg              Random House        28-Feb-12
# 2    David Ulrich  McGraw Hill Professional        20-Jul-12
# 3  Madeleine Roux                   Penguin        15-Oct-19
# 4    Pierce Brown                   Del Rey         9-Feb-16

# %%
# Prepping nyt data table

nyt_df = nyt_rdf[['primary_isbn13','weeks_on_list']]

#nyt_df = books_df[['goodreads_rating', 'gg_rating']]
nyt_df = nyt_df.rename(columns={'primary_isbn13':'isbn', 
                              'weeks_on_list':'weeks'}) 
# Drop any duplicate isbns
nyt_df = nyt_df.drop_duplicates(subset=['isbn'])  

# nyt_df['isbn'].count()
nyt_df
# Out:
#                isbn  weeks
# 0       9.78159E+12    102
# 1        9.7815E+12     81
# 2       9.78053E+12     66
# 3       9.78147E+12     63
# 4       9.78144E+12     58
# ...             ...    ...
# 2161    9.78079E+12      0
# 2173  A00B005C50KA8      0
# 2178  A00B00547KH66      0
# 2199  A00B0052YFNFQ      0
# 2201            NaN      0
#
# [184 rows x 2 columns]

# %%
# Prepping Ratings table

ratings_df = books_df[['isbn', 'goodreads_rating', 'gg_rating']]
ratings_df = ratings_df.rename(columns={'goodreads_rating':'goodreads_rtg', 
                              'gg_rating':'google_rtg'}) 
ratings_df
# Out:
#              isbn  goodreads_rtg  google_rtg
# 0   9780060000000           4.27         4.3
# 1   9780680000000           4.25         4.1
# 2   9780070000000           4.25         3.6
# 3   9780450000000           3.90         4.0
# 4   9780350000000           4.59         4.8
# ..            ...            ...         ...
# 57  9783640000000           4.80         2.5
# 58  9781260000000           4.50         NaN
# 59  9788070000000           3.77         4.6
# 60  9783740000000           5.00         5.0
# 61  9788030000000           4.55         4.7
#
# [62 rows x 3 columns]

# %%
final_ratings_df = pd.merge(ratings_df, nyt_df, on="isbn", how="left")

final_ratings_df["nyt_ind"] = np.where(final_ratings_df['weeks'] >= 1, True, False)

final_ratings_df = final_ratings_df[['isbn', 'google_rtg', 'goodreads_rtg', 'nyt_ind', 'weeks']]

final_ratings_df.head()
# Out:
#             isbn  google_rtg  goodreads_rtg  nyt_ind  weeks
# 0  9780060000000         4.3           4.27    False    NaN
# 1  9780680000000         4.1           4.25    False    NaN
# 2  9780070000000         3.6           4.25    False    NaN
# 3  9780450000000         4.0           3.90    False    NaN
# 4  9780350000000         4.8           4.59    False    NaN

# %%
final_ratings_df.dtypes
# Out:
# isbn              object
# google_rtg       float64
# goodreads_rtg    float64
# nyt_ind             bool
# weeks            float64
# dtype: object

# %% [markdown]
# ## Create database connection

# %%
connection_string = "postgres:postgres@localhost:5432/etl_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
 # Confirm tables
engine.table_names()
# Out:
# ['books', 'ratings']

# %%
final_books_df.to_sql(name='books', con=engine, if_exists='append', index=False)

# %%
final_ratings_df.to_sql(name='ratings', con=engine, if_exists='append', index=False)
